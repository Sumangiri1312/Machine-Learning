# %%
import requests
import pandas as pd

api_key = "614401381f2542ca9ce64e094202f5d2"

url = f"https://newsapi.org/v2/top-headlines?country=us&apiKey={api_key}"

response = requests.get(url)

data = response.json()

df = pd.DataFrame(data['articles'])

print(df.head())
# Out:
#                                               source  \
# 0             {'id': 'nbc-news', 'name': 'NBC News'}
# 1             {'id': 'cbs-news', 'name': 'CBS News'}
# 2  {'id': 'the-wall-street-journal', 'name': 'The...
# 3                   {'id': None, 'name': 'BBC News'}
# 4  {'id': 'associated-press', 'name': 'Associated...
#
#                                    author  \
# 0  Marlene Lenthang, Jean-Nicholas Fievet
# 1                           Faris  Tanyos
# 2                                     WSJ
# 3                                    None
# 4                             Chan Ho-him
#
#                                                title  \
# 0  Prince Harry and Meghan will move back to the ...
# 1  One killed when small plane, state police heli...
# 2  Stock Market Today: Bond Market Steady After T...
# 3  Trump vows tougher economic measures on Iran a...
# 4  Chinese court sentences Evergrande founder to ...
#
#                                          description  \
# 0  The couple has lived in California since 2020....
# 1  One person was killed and two Pennsylvania Sta...
# 2                                               None
# 3  It comes after a 60-day ceasefire expired on M...
# 4  A Chinese court has sentenced Hui Ka Yan, foun...
#
#                                                  url  \
# 0  https://www.nbcnews.com/world/united-kingdom/p...
# 1  https://www.cbsnews.com/news/small-plane-state...
# 2  https://www.wsj.com/livecoverage/stock-market-...
# 3     https://www.bbc.com/news/articles/c2k7e83ynj4o
# 4  https://apnews.com/article/china-evergrande-fo...
#
#                                           urlToImage           publishedAt  \
# 0  https://media-cldnry.s-nbcnews.com/image/uploa...  2026-08-20T10:24:00Z
# 1  https://assets3.cbsnewsstatic.com/hub/i/r/2026...  2026-08-20T10:09:54Z
# 2                                               None  2026-08-20T09:31:00Z
# 3  https://ichef.bbci.co.uk/news/1024/branded_new...  2026-08-20T09:13:18Z
# 4  https://dims.apnews.com/dims4/default/e00d961/...  2026-08-20T09:02:00Z
#
#                                              content
# 0  Prince Harry and his family will leave the sun...
# 1  One person was killed and two Pennsylvania Sta...
# 2                                               None
# 3  "ANY country that allows its financial institu...
# 4  HONG KONG (AP) Chinese property developer Hui ...

# %%
df['source_name'] = df['source'].apply(lambda x: x['name'])

# %%
df = df[['source_name',
         'author',
         'title',
         'publishedAt',
         'url']]

# %%
df
# Out:
#                 source_name                                  author  \
# 0                  NBC News  Marlene Lenthang, Jean-Nicholas Fievet
# 1                  CBS News                           Faris  Tanyos
# 2   The Wall Street Journal                                     WSJ
# 3                  BBC News                                    None
# 4          Associated Press                             Chan Ho-him
# 5                  Politico                           Samuel Benson
# 6                      WJLA                             Kendra Mann
# 7                     Axios                             Barak Ravid
# 8                  Wccftech                            Sarfraz Khan
# 9                       NPR                    The Associated Press
